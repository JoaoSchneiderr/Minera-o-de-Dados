# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoSchneiderr/Minera-o-de-Dados/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação de informações

# %%
# !pip install gdown
# !gdown --id 1Ox5MoVf6vQmSxwAF6XSBOH7J_lY4ugNe -O dados_nova_iguacu_limpo_v7.csv
import pandas as pd
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.25.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Ox5MoVf6vQmSxwAF6XSBOH7J_lY4ugNe
# To: /content/dados_nova_iguacu_limpo_v7.csv
# 100% 351k/351k [00:00<00:00, 118MB/s]

# %%
nova_iguacu_df = pd.read_csv('dados_nova_iguacu_limpo_v7.csv', encoding='latin1', on_bad_lines='skip')
display(nova_iguacu_df.head())
# Out:
#        id      pesid data_inversa   dia_semana   horario  uf     br     km  \
# 0  653257  1469809.0   2025-01-04       sábado  23:00:00  RJ  493.0   66.0
# 1  653257  1469811.0   2025-01-04       sábado  23:00:00  RJ  493.0   66.0
# 2  653414  1470243.0   2025-01-05      domingo  22:50:00  RJ  116.0  181.0
# 3  654387  1472899.0   2025-01-10  sexta-feira  16:30:00  RJ  493.0   73.0
# 4  654568  1473371.0   2025-01-12      domingo  01:00:00  RJ  465.0   18.0
#
#      municipio causa_principal  ... estado_fisico  idade       sexo ilesos  \
# 0  NOVA IGUACU             Não  ...         Ileso     53  Masculino      1
# 1  NOVA IGUACU             Não  ...         Óbito     33  Masculino      0
# 2  NOVA IGUACU             Sim  ...         Ileso     47  Masculino      1
# 3  NOVA IGUACU             Sim  ...         Ileso     51  Masculino      1
# 4  NOVA IGUACU             Sim  ...  Lesões Leves     23  Masculino      0
#
#   feridos_leves feridos_graves mortos   latitude  longitude faixa_etaria
# 0             0              0      0 -43.453331 -43.423492       Adulto
# 1             0              1      1 -43.453331 -43.625050       Adulto
# 2             0              0      0 -22.761312 -43.423492       Adulto
# 3             0              0      0 -22.662866 -43.625050       Adulto
# 4             1              0      0 -22.831354 -43.615128        Jovem
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 1. Quantidade total de acidentes em Nova Iguaçu / Quantidade de acidentes registrados por mês

# %%
acidentes_total = len(nova_iguacu_df)
acidentes_total
# Out:
# 1080

# %%
acidentes_por_mes = nova_iguacu_df.copy()
acidentes_por_mes['data_inversa'] = pd.to_datetime(acidentes_por_mes['data_inversa'])

meses_pt = {
    1: 'Janeiro', 2: 'Fevereiro', 3: 'Março', 4: 'Abril',
    5: 'Maio', 6: 'Junho', 7: 'Julho', 8: 'Agosto',
    9: 'Setembro', 10: 'Outubro', 11: 'Novembro', 12: 'Dezembro'
}

contagem_mes = acidentes_por_mes['data_inversa'].dt.month.value_counts().sort_index()
contagem_mes.index.name = 'Divisão por mês'
display(contagem_mes.rename(index=meses_pt))
# Out:
# Divisão por mês
# Janeiro       74
# Fevereiro     80
# Março         98
# Abril        113
# Maio          81
# Junho         95
# Julho         81
# Agosto        78
# Setembro      82
# Outubro       72
# Novembro     132
# Dezembro      94
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Gravidade dos acidentes por mês em Nova Iguaçu

# %%
nova_iguacu_df['data_inversa'] = pd.to_datetime(nova_iguacu_df['data_inversa'])
nova_iguacu_df['mês'] = nova_iguacu_df['data_inversa'].dt.month

gravidade_mensal = nova_iguacu_df.groupby('mês')[['mortos', 'feridos_graves', 'feridos_leves', 'ilesos']].sum()

print("\nAnálise da Gravidade dos Acidentes por Mês em Nova Iguaçu (Média Mensal):")
avg_mortos_mes = gravidade_mensal['mortos'].mean()
avg_feridos_graves_mes = gravidade_mensal['feridos_graves'].mean()
avg_feridos_leves_mes = gravidade_mensal['feridos_leves'].mean()
print(f"Em média, mensalmente, ocorreram {avg_mortos_mes:.1f} mortes, {avg_feridos_graves_mes:.1f} feridos graves e {avg_feridos_leves_mes:.1f} feridos leves.")

total_mortos_geral = gravidade_mensal['mortos'].sum()
total_feridos_graves_geral = gravidade_mensal['feridos_graves'].sum()
total_feridos_leves_geral = gravidade_mensal['feridos_leves'].sum()
total_ilesos_geral = gravidade_mensal['ilesos'].sum()

print("\nTotais Gerais e Proporções (Ano de 2025) ")
total_mortos = total_mortos_geral
total_feridos = total_feridos_graves_geral + total_feridos_leves_geral
print(f"Total Geral de Mortos: {total_mortos:.0f}")
print(f"Total Geral de Feridos (Graves + Leves): {total_feridos:.0f}")
# Out:
# Análise da Gravidade dos Acidentes por Mês em Nova Iguaçu (Média Mensal):
# Em média, mensalmente, ocorreram 1.4 mortes, 5.6 feridos graves e 34.9 feridos leves.
#
# Totais Gerais e Proporções (Ano de 2025)
# Total Geral de Mortos: 17
# Total Geral de Feridos (Graves + Leves): 486

# %%
classificacao_acidente_contagem = nova_iguacu_df['classificacao_acidente'].value_counts()

acidentes_com_vitimas_fatal = classificacao_acidente_contagem.get('Com Vítimas Fatais', 0)
acidentes_com_vitimas_feridas = classificacao_acidente_contagem.get('Com Vítimas Feridas', 0)
acidentes_sem_vitimas = classificacao_acidente_contagem.get('Sem Vítimas', 0)

total_registros_acidentes = len(nova_iguacu_df)

prop_com_vitimas = ((acidentes_com_vitimas_fatal + acidentes_com_vitimas_feridas) / total_registros_acidentes) * 100
prop_sem_vitimas = (acidentes_sem_vitimas / total_registros_acidentes) * 100

print(f"Proporção de registros de acidentes com vítimas (fatais ou feridas): {prop_com_vitimas:.2f}%")
print(f"Proporção de registros de acidentes sem vítimas: {prop_sem_vitimas:.2f}%")
# Out:
# Proporção de registros de acidentes com vítimas (fatais ou feridas): 89.91%
# Proporção de registros de acidentes sem vítimas: 10.09%

# %%
taxa_acidentes_morte = (acidentes_com_vitimas_fatal / total_registros_acidentes) * 100
print(f"Taxa de registros de acidentes com vítimas fatais: {taxa_acidentes_morte:.2f}%")
# Out:
# Taxa de registros de acidentes com vítimas fatais: 4.91%

# %%
taxa_acidentes_morte = (acidentes_com_vitimas_fatal / total_registros_acidentes) * 100
print(f"Taxa de registros de acidentes com vítimas fatais: {taxa_acidentes_morte:.2f}%")


total_unique_accidents = nova_iguacu_df['id'].nunique()
total_vitimas = total_mortos_geral + total_feridos_graves_geral + total_feridos_leves_geral
media_vitimas_por_acidente = total_vitimas / total_unique_accidents
print(f"Média de vítimas (mortos + feridos graves + feridos leves) por acidente único: {media_vitimas_por_acidente:.2f}")
# Out:
# Taxa de registros de acidentes com vítimas fatais: 4.91%
# Média de vítimas (mortos + feridos graves + feridos leves) por acidente único: 1.15

# %% [markdown]
# ### 3. Tipos de acidentes

# %%
print("\n Tipos de Acidentes Mais Comuns")
tipos_acidentes_comuns = nova_iguacu_df['tipo_acidente'].value_counts().head(10)
display(tipos_acidentes_comuns)
# Out:
#  Tipos de Acidentes Mais Comuns
# tipo_acidente
# Colisão traseira                 301
# Colisão lateral mesmo sentido    203
# Queda de ocupante de veículo     198
# Colisão transversal               64
# Atropelamento de Pedestre         54
# Tombamento                        51
# Engavetamento                     49
# Colisão com objeto                39
# Saída de leito carroçável         35
# Capotamento                       30
# Name: count, dtype: int64

# %%
print("\n Classificação de Acidentes Mais Comuns")
classificacao_acidente_comum = nova_iguacu_df['classificacao_acidente'].value_counts()
display(classificacao_acidente_comum)
# Out:
#  Classificação de Acidentes Mais Comuns
# classificacao_acidente
# Com Vítimas Feridas    918
# Sem Vítimas            109
# Com Vítimas Fatais      53
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Veículos envolvidos

# %%
print("\n Top 10 Tipos de Veículos Mais Comuns nos Acidentes em Nova Iguaçu ")
tipos_veiculo_comuns = nova_iguacu_df['tipo_veiculo'].value_counts().head(10)
display(tipos_veiculo_comuns)
# Out:
#  Top 10 Tipos de Veículos Mais Comuns nos Acidentes em Nova Iguaçu
# tipo_veiculo
# Motocicleta        414
# Automóvel          380
# Caminhonete         55
# Caminhão            41
# Semireboque         39
# Camioneta           34
# Caminhão-trator     27
# Desconhecido        27
# Motoneta            16
# Ônibus              14
# Name: count, dtype: int64

# %%
print("\n CARRO VS MOTO VS CAMINHÃO")
veiculo_especifico = nova_iguacu_df['tipo_veiculo'].value_counts().loc[['Automóvel', 'Motocicleta', 'Caminhão']]
display(veiculo_especifico)
# Out:
#  CARRO VS MOTO VS CAMINHÃO
# tipo_veiculo
# Automóvel      380
# Motocicleta    414
# Caminhão        41
# Name: count, dtype: int64

# %% [markdown]
# ### 5. Perfil das pessoas envolvidas

# %%
bins = [0, 18, 25, 35, 45, 55, 65, 100]
labels = ['0-17', '18-24', '25-34', '35-44', '45-54', '55-64', '65+']

df_perfil['faixa_etaria'] = pd.cut(df_perfil['idade'], bins=bins, labels=labels, right=False)

print("\nDistribuição por Faixa Etária (Indivíduos Envolvidos em Acidentes):")
display(df_perfil['faixa_etaria'].value_counts().sort_index())
# Out:
# Distribuição por Faixa Etária (Indivíduos Envolvidos em Acidentes):
# faixa_etaria
# 0-17      16
# 18-24    112
# 25-34    282
# 35-44    245
# 45-54    156
# 55-64     88
# 65+       41
# Name: count, dtype: int64

# %%
df_vitimas = df_perfil[df_perfil['estado_fisico'].isin(['Ferido Grave', 'Ferido Leve', 'Óbito'])]
idade_media_vitimas = df_vitimas['idade'].mean()

print(f"Idade média das vítimas (Ferido Grave, Ferido Leve ou Morto): {idade_media_vitimas:.2f} anos")
# Out:
# Idade média das vítimas (Ferido Grave, Ferido Leve ou Morto): 26.35 anos

# %%
print("\nDistribuição por Sexo (Indivíduos Envolvidos em Acidentes):")
contagem_sexo = df_perfil['sexo'].value_counts()
display(contagem_sexo)

porcentagem_sexo = df_perfil['sexo'].value_counts(normalize=True) * 100
print("\nPorcentagem por Sexo (Indivíduos Envolvidos em Acidentes):")
display(porcentagem_sexo)
# Out:
# Distribuição por Sexo (Indivíduos Envolvidos em Acidentes):
# sexo
# Masculino        778
# Feminino         192
# Não Informado    107
# Ignorado           3
# Name: count, dtype: int64
# Porcentagem por Sexo (Indivíduos Envolvidos em Acidentes):
# sexo
# Masculino        72.037037
# Feminino         17.777778
# Não Informado     9.907407
# Ignorado          0.277778
# Name: proportion, dtype: float64

# %%
print("\nContagem de Condutores vs. Passageiros:\n")
contagem_condutor_passageiro = df_perfil['tipo_envolvido'].value_counts().loc[['Condutor', 'Passageiro']]
display(contagem_condutor_passageiro)
# Out:
# Contagem de Condutores vs. Passageiros:
# tipo_envolvido
# Condutor      797
# Passageiro    210
# Name: count, dtype: int64

# %% [markdown]
# ### 6. Distribuição temporal

# %%
print("\n Acidentes por Horário em Nova Iguaçu")
acidentes_por_horario = nova_iguacu_df['horario'].value_counts().sort_values(ascending=False)
display(acidentes_por_horario)
# Out:
#  Acidentes por Horário em Nova Iguaçu
# horario
# 08:00:00    32
# 20:30:00    21
# 19:00:00    20
# 20:00:00    20
# 07:00:00    19
#             ..
# 21:50:00     1
# 04:40:00     1
# 06:47:00     1
# 15:23:00     1
# 02:45:00     1
# Name: count, Length: 207, dtype: int64

# %%
print("\nAcidentes por Dia da Semana em Nova Iguaçu")
acidentes_por_dia_semana = nova_iguacu_df['dia_semana'].value_counts().sort_values(ascending=False)
display(acidentes_por_dia_semana)
# Out:
# Acidentes por Dia da Semana em Nova Iguaçu
# dia_semana
# segunda-feira    188
# domingo          181
# sexta-feira      166
# terça-feira      160
# quarta-feira     153
# sábado           147
# quinta-feira      85
# Name: count, dtype: int64

# %%
print("\n Acidentes por Condição Meteorológica em Nova Iguaçu")
acidentes_por_condicao_metereologica = nova_iguacu_df['condicao_metereologica'].value_counts().sort_values(ascending=False)
display(acidentes_por_condicao_metereologica)
# Out:
#  Acidentes por Condição Meteorológica em Nova Iguaçu
# condicao_metereologica
# Céu Claro         790
# Nublado           121
# Chuva              58
# Sol                51
# Garoa/Chuvisco     41
# Ignorado           19
# Name: count, dtype: int64

# %%
print("\n Acidentes por Fase do Dia em Nova Iguaçu ")
acidentes_por_fase_dia = nova_iguacu_df['fase_dia'].value_counts()
display(acidentes_por_fase_dia)
# Out:
#  Acidentes por Fase do Dia em Nova Iguaçu
# fase_dia
# Pleno dia      652
# Plena Noite    334
# Amanhecer       49
# Anoitecer       45
# Name: count, dtype: int64

# %%
print("\n Gravidade dos Acidentes por Fase do Dia em Nova Iguaçu ")

gravidade_por_fase_dia = nova_iguacu_df.groupby('fase_dia')[['mortos', 'feridos_graves', 'feridos_leves']].sum()
display(gravidade_por_fase_dia)
# Out:
#  Gravidade dos Acidentes por Fase do Dia em Nova Iguaçu
#              mortos  feridos_graves  feridos_leves
# fase_dia
# Amanhecer         2               4             14
# Anoitecer         0               2             21
# Plena Noite      11              27            128
# Pleno dia         4              34            256

# %% [markdown]
# ### 7. Condições do ambiente

# %%
print("\nAcidentes por Tipo de Pista em Nova Iguaçu")
acidentes_por_faixa = (
    nova_iguacu_df['tipo_pista']
    .value_counts()
    .reset_index(name='acidentes_por_faixa')
)
display(acidentes_por_faixa.style.hide(axis="index"))
# Out:
# Acidentes por Tipo de Pista em Nova Iguaçu
# <style type="text/css">
# </style>
# <table id="T_8a3d0" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_8a3d0_level0_col0" class="col_heading level0 col0" >tipo_pista</th>
#       <th id="T_8a3d0_level0_col1" class="col_heading level0 col1" >acidentes_por_faixa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8a3d0_row0_col0" class="data row0 col0" >Dupla</td>
#       <td id="T_8a3d0_row0_col1" class="data row0 col1" >694</td>
#     </tr>
#     <tr>
#       <td id="T_8a3d0_row1_col0" class="data row1 col0" >Simples</td>
#       <td id="T_8a3d0_row1_col1" class="data row1 col1" >216</td>
#     </tr>
#     <tr>
#       <td id="T_8a3d0_row2_col0" class="data row2 col0" >Múltipla</td>
#       <td id="T_8a3d0_row2_col1" class="data row2 col1" >170</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("\nAcidentes por Uso do Solo em Nova Iguaçu")
acidentes_por_uso_solo = (
    nova_iguacu_df['uso_solo']
    .value_counts()
    .reset_index(name='total_acidentes')
)

display(acidentes_por_uso_solo.style.hide(axis="index"))
# Out:
# Acidentes por Uso do Solo em Nova Iguaçu
# <style type="text/css">
# </style>
# <table id="T_80778" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_80778_level0_col0" class="col_heading level0 col0" >uso_solo</th>
#       <th id="T_80778_level0_col1" class="col_heading level0 col1" >total_acidentes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_80778_row0_col0" class="data row0 col0" >Sim</td>
#       <td id="T_80778_row0_col1" class="data row0 col1" >714</td>
#     </tr>
#     <tr>
#       <td id="T_80778_row1_col0" class="data row1 col0" >Não</td>
#       <td id="T_80778_row1_col1" class="data row1 col1" >366</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("\nAcidentes por Condição Meteorológica em Nova Iguaçu")
acidentes_por_condicao_metereologica = (
    nova_iguacu_df['condicao_metereologica']
    .value_counts()
    .reset_index(name='total_acidentes')
)

display(
    acidentes_por_condicao_metereologica
    .style
    .hide(axis="index")
    .set_properties(**{'text-align': 'left'})
)
# Out:
# Acidentes por Condição Meteorológica em Nova Iguaçu
# <style type="text/css">
# #T_0655e_row0_col0, #T_0655e_row0_col1, #T_0655e_row1_col0, #T_0655e_row1_col1, #T_0655e_row2_col0, #T_0655e_row2_col1, #T_0655e_row3_col0, #T_0655e_row3_col1, #T_0655e_row4_col0, #T_0655e_row4_col1, #T_0655e_row5_col0, #T_0655e_row5_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_0655e" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_0655e_level0_col0" class="col_heading level0 col0" >condicao_metereologica</th>
#       <th id="T_0655e_level0_col1" class="col_heading level0 col1" >total_acidentes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0655e_row0_col0" class="data row0 col0" >Céu Claro</td>
#       <td id="T_0655e_row0_col1" class="data row0 col1" >790</td>
#     </tr>
#     <tr>
#       <td id="T_0655e_row1_col0" class="data row1 col0" >Nublado</td>
#       <td id="T_0655e_row1_col1" class="data row1 col1" >121</td>
#     </tr>
#     <tr>
#       <td id="T_0655e_row2_col0" class="data row2 col0" >Chuva</td>
#       <td id="T_0655e_row2_col1" class="data row2 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_0655e_row3_col0" class="data row3 col0" >Sol</td>
#       <td id="T_0655e_row3_col1" class="data row3 col1" >51</td>
#     </tr>
#     <tr>
#       <td id="T_0655e_row4_col0" class="data row4 col0" >Garoa/Chuvisco</td>
#       <td id="T_0655e_row4_col1" class="data row4 col1" >41</td>
#     </tr>
#     <tr>
#       <td id="T_0655e_row5_col0" class="data row5 col0" >Ignorado</td>
#       <td id="T_0655e_row5_col1" class="data row5 col1" >19</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("\nAcidentes por Traçado da Via em Nova Iguaçu")
acidentes_por_tracado_via = (
    nova_iguacu_df['tracado_via']
    .value_counts()
    .reset_index(name='total_acidentes')
)
display(
    acidentes_por_tracado_via
    .style
    .hide(axis="index")
    .set_properties(**{'text-align': 'left'})
)
# Out:
# Acidentes por Traçado da Via em Nova Iguaçu
# <style type="text/css">
# #T_39f0a_row0_col0, #T_39f0a_row0_col1, #T_39f0a_row1_col0, #T_39f0a_row1_col1, #T_39f0a_row2_col0, #T_39f0a_row2_col1, #T_39f0a_row3_col0, #T_39f0a_row3_col1, #T_39f0a_row4_col0, #T_39f0a_row4_col1, #T_39f0a_row5_col0, #T_39f0a_row5_col1, #T_39f0a_row6_col0, #T_39f0a_row6_col1, #T_39f0a_row7_col0, #T_39f0a_row7_col1, #T_39f0a_row8_col0, #T_39f0a_row8_col1, #T_39f0a_row9_col0, #T_39f0a_row9_col1, #T_39f0a_row10_col0, #T_39f0a_row10_col1, #T_39f0a_row11_col0, #T_39f0a_row11_col1, #T_39f0a_row12_col0, #T_39f0a_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_39f0a" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_39f0a_level0_col0" class="col_heading level0 col0" >tracado_via</th>
#       <th id="T_39f0a_level0_col1" class="col_heading level0 col1" >total_acidentes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_39f0a_row0_col0" class="data row0 col0" >Reta</td>
#       <td id="T_39f0a_row0_col1" class="data row0 col1" >981</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row1_col0" class="data row1 col0" >Curva</td>
#       <td id="T_39f0a_row1_col1" class="data row1 col1" >43</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row2_col0" class="data row2 col0" >Reta;Em Obras</td>
#       <td id="T_39f0a_row2_col1" class="data row2 col1" >29</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row3_col0" class="data row3 col0" >Em Obras;Reta</td>
#       <td id="T_39f0a_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row4_col0" class="data row4 col0" >Aclive;Reta</td>
#       <td id="T_39f0a_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row5_col0" class="data row5 col0" >Reta;Interseção de Vias</td>
#       <td id="T_39f0a_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row6_col0" class="data row6 col0" >Interseção de Vias</td>
#       <td id="T_39f0a_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row7_col0" class="data row7 col0" >Reta;Aclive</td>
#       <td id="T_39f0a_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row8_col0" class="data row8 col0" >Interseção de Vias;Curva</td>
#       <td id="T_39f0a_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row9_col0" class="data row9 col0" >Interseção de Vias;Em Obras;Reta</td>
#       <td id="T_39f0a_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row10_col0" class="data row10 col0" >Declive;Curva</td>
#       <td id="T_39f0a_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row11_col0" class="data row11 col0" >Desvio Temporário;Reta;Em Obras</td>
#       <td id="T_39f0a_row11_col1" class="data row11 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_39f0a_row12_col0" class="data row12 col0" >Viaduto</td>
#       <td id="T_39f0a_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 8. Localização dos acidentes

# %%
print("\n Acidentes por Rodovia (BR) em Nova Iguaçu ")
acidentes_por_br = nova_iguacu_df['br'].value_counts().reset_index()
acidentes_por_br.columns = ['BR', 'contagem_acidentes']
acidentes_por_br['BR'] = acidentes_por_br['BR'].astype(int)
display(acidentes_por_br.style.hide(axis="index"))
# Out:
#  Acidentes por Rodovia (BR) em Nova Iguaçu
# <style type="text/css">
# </style>
# <table id="T_63f76" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_63f76_level0_col0" class="col_heading level0 col0" >BR</th>
#       <th id="T_63f76_level0_col1" class="col_heading level0 col1" >contagem_acidentes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63f76_row0_col0" class="data row0 col0" >116</td>
#       <td id="T_63f76_row0_col1" class="data row0 col1" >778</td>
#     </tr>
#     <tr>
#       <td id="T_63f76_row1_col0" class="data row1 col0" >465</td>
#       <td id="T_63f76_row1_col1" class="data row1 col1" >185</td>
#     </tr>
#     <tr>
#       <td id="T_63f76_row2_col0" class="data row2 col0" >493</td>
#       <td id="T_63f76_row2_col1" class="data row2 col1" >116</td>
#     </tr>
#     <tr>
#       <td id="T_63f76_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_63f76_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
nova_iguacu_df['br_km'] = nova_iguacu_df['br'].astype(str) + '-' + nova_iguacu_df['km'].astype(str)
acidentes_por_br_km = nova_iguacu_df['br_km'].value_counts()

df_br_km_acidentes = acidentes_por_br_km.reset_index()
df_br_km_acidentes.columns = ['br_km_', 'ACIDENTES']

df_br_km_acidentes[['BR', 'KM']] = df_br_km_acidentes['br_km_'].str.split('-', expand=True)

df_br_km_acidentes = df_br_km_acidentes[['BR', 'KM', 'ACIDENTES']]
df_br_km_acidentes.insert(0, 'Classificação.', range(1, 1 + len(df_br_km_acidentes)))

print("\nContagem de Acidentes por BR e KM:")
display(df_br_km_acidentes.head(10).style.hide(axis="index"))
# Out:
# Contagem de Acidentes por BR e KM:
# <style type="text/css">
# </style>
# <table id="T_6d776" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_6d776_level0_col0" class="col_heading level0 col0" >Classificação.</th>
#       <th id="T_6d776_level0_col1" class="col_heading level0 col1" >BR</th>
#       <th id="T_6d776_level0_col2" class="col_heading level0 col2" >KM</th>
#       <th id="T_6d776_level0_col3" class="col_heading level0 col3" >ACIDENTES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6d776_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6d776_row0_col1" class="data row0 col1" >116.0</td>
#       <td id="T_6d776_row0_col2" class="data row0 col2" >186.0</td>
#       <td id="T_6d776_row0_col3" class="data row0 col3" >111</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6d776_row1_col1" class="data row1 col1" >116.0</td>
#       <td id="T_6d776_row1_col2" class="data row1 col2" >184.0</td>
#       <td id="T_6d776_row1_col3" class="data row1 col3" >92</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6d776_row2_col1" class="data row2 col1" >116.0</td>
#       <td id="T_6d776_row2_col2" class="data row2 col2" >183.0</td>
#       <td id="T_6d776_row2_col3" class="data row2 col3" >79</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6d776_row3_col1" class="data row3 col1" >116.0</td>
#       <td id="T_6d776_row3_col2" class="data row3 col2" >185.0</td>
#       <td id="T_6d776_row3_col3" class="data row3 col3" >73</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_6d776_row4_col1" class="data row4 col1" >116.0</td>
#       <td id="T_6d776_row4_col2" class="data row4 col2" >181.0</td>
#       <td id="T_6d776_row4_col3" class="data row4 col3" >71</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_6d776_row5_col1" class="data row5 col1" >116.0</td>
#       <td id="T_6d776_row5_col2" class="data row5 col2" >187.0</td>
#       <td id="T_6d776_row5_col3" class="data row5 col3" >62</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_6d776_row6_col1" class="data row6 col1" >465.0</td>
#       <td id="T_6d776_row6_col2" class="data row6 col2" >20.0</td>
#       <td id="T_6d776_row6_col3" class="data row6 col3" >59</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_6d776_row7_col1" class="data row7 col1" >116.0</td>
#       <td id="T_6d776_row7_col2" class="data row7 col2" >182.0</td>
#       <td id="T_6d776_row7_col3" class="data row7 col3" >55</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_6d776_row8_col1" class="data row8 col1" >465.0</td>
#       <td id="T_6d776_row8_col2" class="data row8 col2" >21.0</td>
#       <td id="T_6d776_row8_col3" class="data row8 col3" >52</td>
#     </tr>
#     <tr>
#       <td id="T_6d776_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_6d776_row9_col1" class="data row9 col1" >116.0</td>
#       <td id="T_6d776_row9_col2" class="data row9 col2" >188.0</td>
#       <td id="T_6d776_row9_col3" class="data row9 col3" >45</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("\nAnálise de Pontos Críticos por Latitude e Longitude")

nova_iguacu_df['latitude_e_longidute'] = nova_iguacu_df['latitude'].astype(str) + ',' + nova_iguacu_df['longitude'].astype(str)
acidentes_por_lat_lon = nova_iguacu_df['latitude_e_longidute'].value_counts().head(10).reset_index()
acidentes_por_lat_lon.columns = ['latitude_e_longidute', 'total_acidentes']
acidentes_por_lat_lon[['latitude', 'longitude']] = acidentes_por_lat_lon['latitude_e_longidute'].str.split(',', expand=True)

df_lat_lon_acidentes = acidentes_por_lat_lon[['latitude', 'longitude', 'total_acidentes']].copy()
df_lat_lon_acidentes.insert(0, 'Classificação.', range(1, 1 + len(df_lat_lon_acidentes)))

print("\nContagem de Acidentes por Latitude e Longitude:")
display(df_lat_lon_acidentes.style.hide(axis="index"))
# Out:
# Análise de Pontos Críticos por Latitude e Longitude
#
# Contagem de Acidentes por Latitude e Longitude:
# <style type="text/css">
# </style>
# <table id="T_715c6" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_715c6_level0_col0" class="col_heading level0 col0" >Classificação.</th>
#       <th id="T_715c6_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_715c6_level0_col2" class="col_heading level0 col2" >longitude</th>
#       <th id="T_715c6_level0_col3" class="col_heading level0 col3" >total_acidentes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_715c6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_715c6_row0_col1" class="data row0 col1" >-22.73962339</td>
#       <td id="T_715c6_row0_col2" class="data row0 col2" >-43.46276495</td>
#       <td id="T_715c6_row0_col3" class="data row0 col3" >30</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_715c6_row1_col1" class="data row1 col1" >-22.73883756</td>
#       <td id="T_715c6_row1_col2" class="data row1 col2" >-43.47245197</td>
#       <td id="T_715c6_row1_col3" class="data row1 col3" >19</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_715c6_row2_col1" class="data row2 col1" >-22.68140623</td>
#       <td id="T_715c6_row2_col2" class="data row2 col2" >-43.53034051</td>
#       <td id="T_715c6_row2_col3" class="data row2 col3" >14</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_715c6_row3_col1" class="data row3 col1" >-22.74151051</td>
#       <td id="T_715c6_row3_col2" class="data row3 col2" >-43.45351823</td>
#       <td id="T_715c6_row3_col3" class="data row3 col3" >11</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_715c6_row4_col1" class="data row4 col1" >-22.7380709</td>
#       <td id="T_715c6_row4_col2" class="data row4 col2" >-43.48213999</td>
#       <td id="T_715c6_row4_col3" class="data row4 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_715c6_row5_col1" class="data row5 col1" >-22.846828</td>
#       <td id="T_715c6_row5_col2" class="data row5 col2" >-43.605339</td>
#       <td id="T_715c6_row5_col3" class="data row5 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_715c6_row6_col1" class="data row6 col1" >-22.74185146</td>
#       <td id="T_715c6_row6_col2" class="data row6 col2" >-43.52263989</td>
#       <td id="T_715c6_row6_col3" class="data row6 col3" >8</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_715c6_row7_col1" class="data row7 col1" >-22.84934285</td>
#       <td id="T_715c6_row7_col2" class="data row7 col2" >-43.603184</td>
#       <td id="T_715c6_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_715c6_row8_col1" class="data row8 col1" >-22.688636</td>
#       <td id="T_715c6_row8_col2" class="data row8 col2" >-43.439037</td>
#       <td id="T_715c6_row8_col3" class="data row8 col3" >7</td>
#     </tr>
#     <tr>
#       <td id="T_715c6_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_715c6_row9_col1" class="data row9 col1" >-22.82497926</td>
#       <td id="T_715c6_row9_col2" class="data row9 col2" >-43.61910559</td>
#       <td id="T_715c6_row9_col3" class="data row9 col3" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 9. Análise do Acidente Mais Grave

# %%
acidentes = nova_iguacu_df.groupby('id').sum(numeric_only=True)
acidentes['feridos'] = acidentes['feridos_graves'] + acidentes['feridos_leves']

id_acidente = acidentes['mortos'].idxmax()
dados = nova_iguacu_df[nova_iguacu_df['id'] == id_acidente]

print("Mortos:", int(acidentes.loc[id_acidente, 'mortos']))
print("Feridos:", int(acidentes.loc[id_acidente, 'feridos']))
print("Envolvidos:", len(dados))

linha = dados.iloc[0]
print("BR:", linha['br'])
print("KM:", linha['km'])
print("Dia:", linha['dia_semana'])
print("Hora:", linha['horario'])
print("Causa:", linha['causa_acidente'])

print("Veículos:", ", ".join(dados['tipo_veiculo'].unique()))
# Out:
# Mortos: 2
# Feridos: 0
# Envolvidos: 3
# BR: 493.0
# KM: 59.0
# Dia: quarta-feira
# Hora: 20:00:00
# Causa: Pedestre andava na pista
# Veículos: Bicicleta, Automóvel, Desconhecido

# %%
acidentes = nova_iguacu_df.groupby('id').sum(numeric_only=True)
acidentes['feridos'] = acidentes['feridos_graves'] + acidentes['feridos_leves']

id_acidente = acidentes['feridos'].idxmax()
dados = nova_iguacu_df[nova_iguacu_df['id'] == id_acidente]

print("Mortos:", int(acidentes.loc[id_acidente, 'mortos']))
print("Feridos:", int(acidentes.loc[id_acidente, 'feridos']))
print("Envolvidos:", len(dados))

linha = dados.iloc[0]
print("BR:", linha['br'])
print("KM:", linha['km'])
print("Dia:", linha['dia_semana'])
print("Hora:", linha['horario'])
print("Causa:", linha['causa_acidente'])

print("Veículos:", ", ".join(dados['tipo_veiculo'].unique()))
# Out:
# Mortos: 0
# Feridos: 4
# Envolvidos: 4
# BR: 116.0
# KM: 183.0
# Dia: domingo
# Hora: 21:30:00
# Causa: Ausência de reação do condutor
# Veículos: Motocicleta

# %%
acidentes = nova_iguacu_df.groupby('id').sum(numeric_only=True)

id_acidente = nova_iguacu_df['id'].value_counts().idxmax()
dados = nova_iguacu_df[nova_iguacu_df['id'] == id_acidente]

print("Mortos:", int(acidentes.loc[id_acidente, 'mortos']))
print("Feridos:", int(acidentes.loc[id_acidente, 'feridos_graves'] + acidentes.loc[id_acidente, 'feridos_leves']))
print("Envolvidos:", len(dados))

linha = dados.iloc[0]
print("BR:", linha['br'])
print("KM:", linha['km'])
print("Dia:", linha['dia_semana'])
print("Hora:", linha['horario'])
print("Causa:", linha['causa_acidente'])

print("Veículos:", ", ".join(dados['tipo_veiculo'].unique()))
# Out:
# Mortos: 0
# Feridos: 0
# Envolvidos: 14
# BR: 493.0
# KM: 77.0
# Dia: terça-feira
# Hora: 08:20:00
# Causa: Manobra de mudança de faixa
# Veículos: Semireboque, Utilitário, Caminhão-trator, Desconhecido

# %% [markdown]
# ### Investigação piores acidentes

# %% [markdown]
# **Resultado da pesquisa Acidente com maior número de feridos e Acidente com maior número de mortos**:
#
# Após busca em portais de notícias (R7, Record, G1, O Dia, Jornal Destaque Baixada), redes sociais e comunicados oficiais, não foi possivel localizar qualquer matéria ou boletim de ocorrência público que descreva um acidente de moto em Nova Iguaçu em 15/06/2025 às 21h30 nem o atropelamento fatal de 23/04/2025.
#
# É possível que o caso tenha sido apenas registrado em bancos de dados internos (como Detran/RJ) sem cobertura jornalística, ou publicado apenas em mídias restritas.

# %% [markdown]
# ### Análise Geral Final

# %% [markdown]
# A análise dos dados de acidentes nas rodovias federais de Nova Iguaçu em 2025 mostrou que foram registrados 1.081 acidentes ao longo do ano.
#
# A maior parte das ocorrências aconteceu na **BR-116**, que concentrou aproximadamente **72%** dos acidentes com **778 registros**. Em seguida aparecem a BR-465 com cerca de 17% e a BR-493 com aproximadamente 10%. Alguns trechos da BR-116, especialmente entre os quilômetros 181 e 187, apresentaram maior concentração de acidentes, indicando possíveis pontos críticos de trânsito.
#
# Ao longo do ano, **novembro foi o mês com maior número de acidentes**, representando cerca de **12,2% do total de 132 registros**. Já outubro teve aproximadamente 6,7% e janeiro cerca de 6,8% , sendo os **meses com menor registro.**
#
# No total, os acidentes resultaram em **17 mortes e 486 pessoas feridas**. Considerando os registros, cerca de 89,8% dos acidentes tiveram vítimas, enquanto aproximadamente 10,1% ocorreram sem vítimas.
#
# Entre os tipos de acidentes, os **mais comuns foram colisão traseira**, responsável por cerca de **27,8% **dos casos , colisão lateral no mesmo sentido com aproximadamente **18,8%** e queda de ocupante de veículo, representando cerca de **18,3%**.
#
# Em relação aos veículos envolvidos, **motocicletas em registros 414 vezes e automóveis 380**, sendo os tipos mais frequentes.
#
# A análise também mostrou que a maior parte das pessoas envolvidas nos acidentes era do sexo masculino aproximadamente** 72%**, enquanto **17,8%** **eram do sexo feminino**.
#
# Quanto ao momento das ocorrências, cerca de 60,3% dos acidentes aconteceram durante o dia e 30,9% durante a noite. Apesar de menos frequentes, **os acidentes noturnos concentraram aproximadamente 64,7% das mortes registradas**.
#
# De forma geral, os dados indicam que os acidentes em Nova Iguaçu estão concentrados em rodovias de grande movimento, principalmente na BR-116, envolvendo com maior frequência motociclistas e condutores do sexo masculino, e podem estar relacionados a fatores como alto fluxo de veículos, comportamento de risco e atenção no trânsito.
